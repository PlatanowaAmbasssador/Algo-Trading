# %%
# import libraries
from performance_metrics import *
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # CAC 40

# %%
STOCK_NAME = "CAC 40"
STOCK_NAME_edited = "**CAC 40**"
NAME = "RANDOM_SEARCH_1"
PATH_STOCK_NAME = f'CAC/Sensitivity Analysis/{NAME}'

df_EC_ARIMA_LO_BM = pd.read_csv(f'../ARIMA/Results/{PATH_STOCK_NAME}/Visualisations/df_EC_LO_MAIN.csv')
df_EC_LSTM_LO_BM = pd.read_csv(f'../LSTM/Results/{PATH_STOCK_NAME}/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LSTM_LO_BM = pd.read_csv(f'../ARIMA-LSTM/Results/{PATH_STOCK_NAME}/Visualisations/df_EC_LO_MAIN.csv')

df_EC_ARIMA_LS_BM = pd.read_csv(f'../ARIMA/Results/{PATH_STOCK_NAME}/Visualisations/df_EC_LS_MAIN.csv')
df_EC_LSTM_LS_BM = pd.read_csv(f'../LSTM/Results/{PATH_STOCK_NAME}/Visualisations/df_EC_LS_MAIN.csv')
df_EC_ARIMA_LSTM_LS_BM = pd.read_csv(f'../ARIMA-LSTM/Results/{PATH_STOCK_NAME}/Visualisations/df_EC_LS_MAIN.csv')

# %%
df_perf_metr_LO = performance_metrics("**Long Only**", df_EC_ARIMA_LSTM_LO_BM, df_EC_ARIMA_LO_BM, df_EC_LSTM_LO_BM, df_EC_ARIMA_LSTM_LO_BM, STOCK_NAME_edited)

# %%
df_perf_metr_LS = performance_metrics("**Long Short**", df_EC_ARIMA_LSTM_LS_BM, df_EC_ARIMA_LS_BM, df_EC_LSTM_LS_BM, df_EC_ARIMA_LSTM_LS_BM, STOCK_NAME_edited)

# %%
df_perf_metr_LO
# Out:
#                              ARC(%)     ASD(%)      MD(%)       MLD  \
# **Long Only**
#                **CAC 40**      3.52      21.44      59.16     14.04
#                     ARIMA     -4.38  **15.14**      65.53      16.5
#                      LSTM      3.12       16.1  **42.35**  **5.38**
#                LSTM-ARIMA  **5.02**      15.43      53.65      8.33
#
#                   IR*(%)   IR**(%)
# **Long Only**
#                    16.43      0.98
#                        0         0
#                     19.4      1.43
#                **32.52**  **3.04**

# %%
df_perf_metr_LS
# Out:
#                                ARC(%)     ASD(%)      MD(%)       MLD  \
# **Long Short**
#                 **CAC 40**       3.52      21.44      59.16     14.04
#                      ARIMA      -1.81  **21.43**      72.02     14.95
#                       LSTM       3.56      21.44      60.73      9.01
#                 LSTM-ARIMA  **11.06**  **21.43**  **39.91**  **2.91**
#
#                   IR*(%)    IR**(%)
# **Long Short**
#                    16.43       0.98
#                        0          0
#                    16.59       0.97
#                 **51.6**  **14.29**

# %%
STOCK_NAME_FOLDER = f'./PERF_METR_RESULTS/{STOCK_NAME}/{NAME}'

import os
if not os.path.exists(STOCK_NAME_FOLDER):
    os.makedirs(STOCK_NAME_FOLDER)

df_perf_metr_LO.to_csv(f'{STOCK_NAME_FOLDER}/df_perf_metr_LO.csv')
df_perf_metr_LS.to_csv(f'{STOCK_NAME_FOLDER}/df_perf_metr_LS.csv')

# %% [markdown]
# # Sensitivity Analysis - LSTM

# %%
STOCK_NAME = "CAC 40"

df_EC_LSTM_LO_BM = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/RANDOM_SEARCH_1/Visualisations/df_EC_LO_MAIN.csv')
df_EC_LSTM_LS_BM = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/RANDOM_SEARCH_1/Visualisations/df_EC_LS_MAIN.csv')

# df_EC_LSTM_LO_SENS_0 = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/SENS_0/Visualisations/df_EC_LO_MAIN.csv')
# df_EC_LSTM_LS_SENS_0 = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/SENS_0/Visualisations/df_EC_LS_MAIN.csv')

# df_EC_LSTM_LO_SENS_0A = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/SENS_0A/Visualisations/df_EC_LO_MAIN.csv')
# df_EC_LSTM_LS_SENS_0A = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/SENS_0A/Visualisations/df_EC_LS_MAIN.csv')

df_EC_LSTM_LO_SENS_1 = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/SENS_1/Visualisations/df_EC_LO_MAIN.csv')
df_EC_LSTM_LS_SENS_1 = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/SENS_1/Visualisations/df_EC_LS_MAIN.csv')

df_EC_LSTM_LO_SENS_1A = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/SENS_1A/Visualisations/df_EC_LO_MAIN.csv')
df_EC_LSTM_LS_SENS_1A = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/SENS_1A/Visualisations/df_EC_LS_MAIN.csv')

df_EC_LSTM_LO_SENS_2 = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/SENS_2/Visualisations/df_EC_LO_MAIN.csv')
df_EC_LSTM_LS_SENS_2 = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/SENS_2/Visualisations/df_EC_LS_MAIN.csv')

df_EC_LSTM_LO_SENS_2A = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/SENS_2A/Visualisations/df_EC_LO_MAIN.csv')
df_EC_LSTM_LS_SENS_2A = pd.read_csv(f'../LSTM/Results/CAC/Sensitivity Analysis/SENS_2A/Visualisations/df_EC_LS_MAIN.csv')

# %%
df_perf_metr_LO_LSTM = performance_metrics_SENS("**Long Only**", 
                                                df_EC_LSTM_LO_BM, 
                                                df_EC_LSTM_LO_BM, 
                                                # df_EC_LSTM_LO_SENS_0,
                                                # df_EC_LSTM_LO_SENS_0A,
                                                df_EC_LSTM_LO_SENS_1, 
                                                df_EC_LSTM_LO_SENS_1A, 
                                                df_EC_LSTM_LO_SENS_2, 
                                                df_EC_LSTM_LO_SENS_2A,
                                                STOCK_NAME_edited,
                                                'Panel I', 'Panel J')

# %%
df_perf_metr_LS_LSTM = performance_metrics_SENS_LS("**Long Short**", 
                                                df_EC_LSTM_LS_BM, 
                                                df_EC_LSTM_LS_BM, 
                                                # df_EC_LSTM_LS_SENS_0,
                                                # df_EC_LSTM_LS_SENS_0A,
                                                df_EC_LSTM_LS_SENS_1, 
                                                df_EC_LSTM_LS_SENS_1A, 
                                                df_EC_LSTM_LS_SENS_2, 
                                                df_EC_LSTM_LS_SENS_2A,
                                                STOCK_NAME_edited,
                                                'Panel K', 'Panel L')

# %%
df_perf_metr_LO_LSTM
# Out:
#                                                           ARC(%)     ASD(%)  \
# &nbsp;                                      **CAC 40**      3.52      21.44
# &nbsp;                                          &nbsp;       NaN        NaN
# **Long Only**              Base Case (Dropout = 0.075)      3.12       16.1
# **Panel I: Dropout Rate**               Dropout = 0.05  **5.62**      16.79
#                                          Dropout = 0.1      2.71  **14.56**
# None                                            &nbsp;       NaN        NaN
# **Panel J: Batch Size**    Base Case (Batch Size = 32)      3.12       16.1
#                                        Batch Size = 16      3.22  **13.91**
#                                        Batch Size = 64  **3.69**      16.98
# None                                            &nbsp;       NaN        NaN
#
#                                MD(%)       MLD     IR*(%)   IR**(%)
# ...

# %%
df_perf_metr_LS_LSTM
# Out:
#                                                           ARC(%)     ASD(%)  \
# **Long Short**             Base Case (Dropout = 0.075)  **3.56**      21.44
# **Panel K: Dropout Rate**               Dropout = 0.05     -1.34  **21.43**
#                                          Dropout = 0.1      1.75      21.44
# None                                            &nbsp;       NaN        NaN
# **Panel L: Batch Size**    Base Case (Batch Size = 32)      3.56      21.44
#                                        Batch Size = 16      -1.5      21.46
#                                        Batch Size = 64  **3.82**  **21.43**
# None                                            &nbsp;       NaN        NaN
#
#                                MD(%)       MLD     IR*(%)   IR**(%)
# **Long Short**             **60.73**      9.01  **16.59**  **0.97**
# **Panel K: Dropout Rate**      65.66  **8.49**        0.0       0.0
#                                66.37  **8.49**       8.16      0.22
# ...

# %%
df_perf_metr_LO_LSTM.to_csv(f'./PERF_METR_RESULTS/{STOCK_NAME}/df_perf_metr_LO_LSTM.csv')
df_perf_metr_LS_LSTM.to_csv(f'./PERF_METR_RESULTS/{STOCK_NAME}/df_perf_metr_LS_LSTM.csv')

# %% [markdown]
# # Sensitivity Analysis - ARIMA-LSTM

# %%
STOCK_NAME = "CAC 40"

df_EC_ARIMA_LSTM_LO_BM = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/RANDOM_SEARCH_1/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LSTM_LS_BM = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/RANDOM_SEARCH_1/Visualisations/df_EC_LS_MAIN.csv')

# df_EC_ARIMA_LSTM_LO_SENS_0 = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/SENS_0/Visualisations/df_EC_LO_MAIN.csv')
# df_EC_ARIMA_LSTM_LS_SENS_0 = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/SENS_0/Visualisations/df_EC_LS_MAIN.csv')

# df_EC_ARIMA_LSTM_LO_SENS_0A = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/SENS_0A/Visualisations/df_EC_LO_MAIN.csv')
# df_EC_ARIMA_LSTM_LS_SENS_0A = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/SENS_0A/Visualisations/df_EC_LS_MAIN.csv')

df_EC_ARIMA_LSTM_LO_SENS_1 = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/SENS_1/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LSTM_LS_SENS_1 = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/SENS_1/Visualisations/df_EC_LS_MAIN.csv')

df_EC_ARIMA_LSTM_LO_SENS_1A = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/SENS_1A/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LSTM_LS_SENS_1A = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/SENS_1A/Visualisations/df_EC_LS_MAIN.csv')

df_EC_ARIMA_LSTM_LO_SENS_2 = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/SENS_2/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LSTM_LS_SENS_2 = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/SENS_2/Visualisations/df_EC_LS_MAIN.csv')

df_EC_ARIMA_LSTM_LO_SENS_2A = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/SENS_2A/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LSTM_LS_SENS_2A = pd.read_csv(f'../ARIMA-LSTM/Results/CAC/Sensitivity Analysis/SENS_2A/Visualisations/df_EC_LS_MAIN.csv')

# %%
df_perf_metr_LO_ARIMA_LSTM = performance_metrics_SENS("**Long Only**", 
                                                      df_EC_ARIMA_LSTM_LO_BM, 
                                                      df_EC_ARIMA_LSTM_LO_BM, 
                                                    #   df_EC_ARIMA_LSTM_LO_SENS_0,
                                                    #   df_EC_ARIMA_LSTM_LO_SENS_0A,
                                                      df_EC_ARIMA_LSTM_LO_SENS_1, 
                                                      df_EC_ARIMA_LSTM_LO_SENS_1A, 
                                                      df_EC_ARIMA_LSTM_LO_SENS_2, 
                                                      df_EC_ARIMA_LSTM_LO_SENS_2A, 
                                                      STOCK_NAME_edited,
                                                      'Panel I', 'Panel J')

# %%
df_perf_metr_LS_ARIMA_LSTM = performance_metrics_SENS_LS("**Long Short**", 
                                                      df_EC_ARIMA_LSTM_LS_BM, 
                                                      df_EC_ARIMA_LSTM_LS_BM, 
                                                    #   df_EC_ARIMA_LSTM_LS_SENS_0,
                                                    #   df_EC_ARIMA_LSTM_LS_SENS_0A,
                                                      df_EC_ARIMA_LSTM_LS_SENS_1, 
                                                      df_EC_ARIMA_LSTM_LS_SENS_1A, 
                                                      df_EC_ARIMA_LSTM_LS_SENS_2, 
                                                      df_EC_ARIMA_LSTM_LS_SENS_2A, 
                                                      STOCK_NAME_edited,
                                                      'Panel K', 'Panel L')

# %%
df_perf_metr_LO_ARIMA_LSTM
# Out:
#                                                           ARC(%)     ASD(%)  \
# &nbsp;                                      **CAC 40**      3.52      21.44
# &nbsp;                                          &nbsp;       NaN        NaN
# **Long Only**              Base Case (Dropout = 0.075)  **5.02**      15.43
# **Panel I: Dropout Rate**               Dropout = 0.05      2.55  **15.34**
#                                          Dropout = 0.1      0.21      16.86
# None                                            &nbsp;       NaN        NaN
# **Panel J: Batch Size**    Base Case (Batch Size = 32)  **5.02**  **15.43**
#                                        Batch Size = 16     -0.61      17.15
#                                        Batch Size = 64     -0.95      15.78
# None                                            &nbsp;       NaN        NaN
#
#                                MD(%)       MLD     IR*(%)   IR**(%)
# ...

# %%
df_perf_metr_LS_ARIMA_LSTM
# Out:
#                                                            ARC(%)     ASD(%)  \
# **Long Short**             Base Case (Dropout = 0.075)  **11.06**  **21.43**
# **Panel K: Dropout Rate**               Dropout = 0.05       8.64      21.44
#                                          Dropout = 0.1        5.7      21.44
# None                                            &nbsp;        NaN        NaN
# **Panel L: Batch Size**    Base Case (Batch Size = 32)  **11.06**  **21.43**
#                                        Batch Size = 16        2.4      21.46
#                                        Batch Size = 64      -0.89      21.44
# None                                            &nbsp;        NaN        NaN
#
#                                MD(%)       MLD    IR*(%)    IR**(%)
# **Long Short**                 39.91  **2.91**  **51.6**  **14.29**
# **Panel K: Dropout Rate**  **32.86**      3.09     40.31       10.6
#                                39.43      7.27     26.57       3.84
# ...

# %%
df_perf_metr_LO_ARIMA_LSTM.to_csv(f'./PERF_METR_RESULTS/{STOCK_NAME}/df_perf_metr_LO_ARIMA_LSTM.csv')
df_perf_metr_LS_ARIMA_LSTM.to_csv(f'./PERF_METR_RESULTS/{STOCK_NAME}/df_perf_metr_LS_ARIMA_LSTM.csv')

# %% [markdown]
# # Sensitivity Analysis - ARIMA

# %%
STOCK_NAME = "CAC 40"

df_EC_ARIMA_LO_BM = pd.read_csv(f'../ARIMA/Results/CAC/Sensitivity Analysis/RANDOM_SEARCH_1/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LS_BM = pd.read_csv(f'../ARIMA/Results/CAC/Sensitivity Analysis/RANDOM_SEARCH_1/Visualisations/df_EC_LS_MAIN.csv')

# df_EC_ARIMA_LO_SENS_0 = pd.read_csv(f'../ARIMA/Results/CAC/Sensitivity Analysis/SENS_0/Visualisations/df_EC_LO_MAIN.csv')
# df_EC_ARIMA_LS_SENS_0 = pd.read_csv(f'../ARIMA/Results/CAC/Sensitivity Analysis/SENS_0/Visualisations/df_EC_LS_MAIN.csv')

# df_EC_ARIMA_LO_SENS_0A = pd.read_csv(f'../ARIMA/Results/CAC/Sensitivity Analysis/SENS_0A/Visualisations/df_EC_LO_MAIN.csv')
# df_EC_ARIMA_LS_SENS_0A = pd.read_csv(f'../ARIMA/Results/CAC/Sensitivity Analysis/SENS_0A/Visualisations/df_EC_LS_MAIN.csv')

df_EC_ARIMA_LO_SENS_B = pd.read_csv(f'../ARIMA/Results/CAC/Sensitivity Analysis/SENS_B/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LS_SENS_B = pd.read_csv(f'../ARIMA/Results/CAC/Sensitivity Analysis/SENS_B/Visualisations/df_EC_LS_MAIN.csv')

df_EC_ARIMA_LO_SENS_C = pd.read_csv(f'../ARIMA/Results/CAC/Sensitivity Analysis/SENS_C/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LS_SENS_C = pd.read_csv(f'../ARIMA/Results/CAC/Sensitivity Analysis/SENS_C/Visualisations/df_EC_LS_MAIN.csv')

# %%
df_perf_metr_LO_ARIMA = performance_metrics_SENS_ARIMA("**Long Only**", 
                                                      df_EC_ARIMA_LO_BM, 
                                                      df_EC_ARIMA_LO_BM, 
                                                    #   df_EC_ARIMA_LO_SENS_0,
                                                    #   df_EC_ARIMA_LO_SENS_0A,
                                                      df_EC_ARIMA_LO_SENS_B, 
                                                      df_EC_ARIMA_LO_SENS_C, 
                                                      STOCK_NAME_edited)

# %%
df_perf_metr_LS_ARIMA = performance_metrics_SENS_ARIMA_LS("**Long Short**", 
                                                      df_EC_ARIMA_LS_BM, 
                                                      df_EC_ARIMA_LS_BM, 
                                                    #   df_EC_ARIMA_LS_SENS_0,
                                                    #   df_EC_ARIMA_LS_SENS_0A,
                                                      df_EC_ARIMA_LS_SENS_B, 
                                                      df_EC_ARIMA_LS_SENS_C, 
                                                      STOCK_NAME_edited)

# %%
df_perf_metr_LO_ARIMA
# Out:
#                                                ARC(%)     ASD(%)      MD(%)  \
#                                 **CAC 40**       3.52      21.44      59.16
#                                     &nbsp;        NaN        NaN        NaN
# **Long Only**                    Base Case  **-4.38**      15.14  **65.53**
#                  Order Range = {0-3,1,0-3}      -5.62       15.1      73.12
#                Information Criterion = BIC      -4.95  **15.07**      69.27
#                                     &nbsp;        NaN        NaN        NaN
#
#                     MLD   IR*(%)  IR**(%)
#                   14.04    16.43     0.98
#                     NaN      NaN      NaN
# **Long Only**  **16.5**  **0.0**  **0.0**
#                **16.5**  **0.0**  **0.0**
#                **16.5**  **0.0**  **0.0**
#                     NaN      NaN      NaN

# %%
df_perf_metr_LS_ARIMA
# Out:
#                                                 ARC(%)     ASD(%)      MD(%)  \
# **Long Short**                    Base Case  **-1.81**  **21.43**  **72.02**
#                   Order Range = {0-3,1,0-3}      -4.35  **21.43**      82.97
#                 Information Criterion = BIC      -2.97  **21.43**      77.67
#                                      &nbsp;        NaN        NaN        NaN
#
#                       MLD   IR*(%)  IR**(%)
# **Long Short**  **14.95**  **0.0**  **0.0**
#                 **14.95**  **0.0**  **0.0**
#                 **14.95**  **0.0**  **0.0**
#                       NaN      NaN      NaN

# %%
df_perf_metr_LO_ARIMA.to_csv(f'./PERF_METR_RESULTS/{STOCK_NAME}/df_perf_metr_LO_ARIMA.csv')
df_perf_metr_LS_ARIMA.to_csv(f'./PERF_METR_RESULTS/{STOCK_NAME}/df_perf_metr_LS_ARIMA.csv')
