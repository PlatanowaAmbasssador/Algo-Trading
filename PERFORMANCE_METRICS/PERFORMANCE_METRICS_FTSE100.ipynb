# %%
# import libraries
from performance_metrics import *
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # FTSE 100

# %%
STOCK_NAME = "FTSE 100"
STOCK_NAME_edited = "**FTSE 100**"
NAME = "RANDOM_SEARCH_1"
PATH_STOCK_NAME = f'FTSE100/Sensitivity Analysis/{NAME}'
PATH_STOCK_NAME_1= f'FTSE100/Sensitivity Analysis/RANDOM_SEARCH_1A'

df_EC_ARIMA_LO_BM = pd.read_csv(f'../ARIMA/Results/{PATH_STOCK_NAME}/Visualisations/df_EC_LO_MAIN.csv')
df_EC_LSTM_LO_BM = pd.read_csv(f'../LSTM/Results/{PATH_STOCK_NAME}/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LSTM_LO_BM = pd.read_csv(f'../ARIMA-LSTM/Results/{PATH_STOCK_NAME_1}/Visualisations/df_EC_LO_MAIN.csv')

df_EC_ARIMA_LS_BM = pd.read_csv(f'../ARIMA/Results/{PATH_STOCK_NAME}/Visualisations/df_EC_LS_MAIN.csv')
df_EC_LSTM_LS_BM = pd.read_csv(f'../LSTM/Results/{PATH_STOCK_NAME}/Visualisations/df_EC_LS_MAIN.csv')
df_EC_ARIMA_LSTM_LS_BM = pd.read_csv(f'../ARIMA-LSTM/Results/{PATH_STOCK_NAME_1}/Visualisations/df_EC_LS_MAIN.csv')

# %%
df_perf_metr_LO = performance_metrics("**Long Only**", df_EC_LSTM_LO_BM, df_EC_ARIMA_LO_BM, df_EC_LSTM_LO_BM, df_EC_ARIMA_LSTM_LO_BM, STOCK_NAME_edited)

# %%
df_perf_metr_LS = performance_metrics("**Long Short**", df_EC_LSTM_LO_BM, df_EC_ARIMA_LS_BM, df_EC_LSTM_LS_BM, df_EC_ARIMA_LSTM_LS_BM, STOCK_NAME_edited)

# %%
df_perf_metr_LO
# Out:
#                                ARC(%)     ASD(%)      MD(%)       MLD  \
# **Long Only**
#                **FTSE 100**      2.39      18.03      47.83      5.94
#                       ARIMA     -3.78  **12.88**      58.12     12.55
#                        LSTM      2.68      14.32      34.93      3.61
#                  LSTM-ARIMA  **5.47**      13.79  **30.22**  **0.91**
#
#                   IR*(%)   IR**(%)
# **Long Only**
#                    13.27      0.66
#                        0         0
#                    18.75      1.44
#                **39.71**  **7.19**

# %%
df_perf_metr_LS
# Out:
#                                  ARC(%)     ASD(%)      MD(%)       MLD  \
# **Long Short**
#                 **FTSE 100**       2.39      18.03      47.83  **5.94**
#                        ARIMA       0.84      18.04      53.65      8.03
#                         LSTM       2.28      18.03      42.92      11.3
#                   LSTM-ARIMA  **10.98**  **18.02**  **40.17**     10.89
#
#                    IR*(%)    IR**(%)
# **Long Short**
#                     13.27       0.66
#                      4.66       0.07
#                     12.67       0.67
#                 **60.92**  **16.65**

# %%
STOCK_NAME_FOLDER = f'./PERF_METR_RESULTS/{STOCK_NAME}/{NAME}'

import os
if not os.path.exists(STOCK_NAME_FOLDER):
    os.makedirs(STOCK_NAME_FOLDER)

df_perf_metr_LO.to_csv(f'{STOCK_NAME_FOLDER}/df_perf_metr_LO.csv')
df_perf_metr_LS.to_csv(f'{STOCK_NAME_FOLDER}/df_perf_metr_LS.csv')

# %% [markdown]
# # Sensitivity Analysis - LSTM

# %%
STOCK_NAME = "FTSE 100"

df_EC_LSTM_LO_BM = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/RANDOM_SEARCH_1/Visualisations/df_EC_LO_MAIN.csv')
df_EC_LSTM_LS_BM = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/RANDOM_SEARCH_1/Visualisations/df_EC_LS_MAIN.csv')

# df_EC_LSTM_LO_SENS_0 = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/SENS_0/Visualisations/df_EC_LO_MAIN.csv')
# df_EC_LSTM_LS_SENS_0 = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/SENS_0/Visualisations/df_EC_LS_MAIN.csv')

# df_EC_LSTM_LO_SENS_0A = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/SENS_0A/Visualisations/df_EC_LO_MAIN.csv')
# df_EC_LSTM_LS_SENS_0A = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/SENS_0A/Visualisations/df_EC_LS_MAIN.csv')

df_EC_LSTM_LO_SENS_1 = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/SENS_1/Visualisations/df_EC_LO_MAIN.csv')
df_EC_LSTM_LS_SENS_1 = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/SENS_1/Visualisations/df_EC_LS_MAIN.csv')

df_EC_LSTM_LO_SENS_1A = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/SENS_1A/Visualisations/df_EC_LO_MAIN.csv')
df_EC_LSTM_LS_SENS_1A = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/SENS_1A/Visualisations/df_EC_LS_MAIN.csv')

df_EC_LSTM_LO_SENS_2 = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/SENS_2/Visualisations/df_EC_LO_MAIN.csv')
df_EC_LSTM_LS_SENS_2 = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/SENS_2/Visualisations/df_EC_LS_MAIN.csv')

df_EC_LSTM_LO_SENS_2A = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/SENS_2A/Visualisations/df_EC_LO_MAIN.csv')
df_EC_LSTM_LS_SENS_2A = pd.read_csv(f'../LSTM/Results/FTSE100/Sensitivity Analysis/SENS_2A/Visualisations/df_EC_LS_MAIN.csv')

# %%
df_perf_metr_LO_LSTM = performance_metrics_SENS("**Long Only**", 
                                                df_EC_LSTM_LO_BM, 
                                                df_EC_LSTM_LO_BM, 
                                                # df_EC_LSTM_LO_SENS_0,
                                                # df_EC_LSTM_LO_SENS_0A,
                                                df_EC_LSTM_LO_SENS_1, 
                                                df_EC_LSTM_LO_SENS_1A, 
                                                df_EC_LSTM_LO_SENS_2, 
                                                df_EC_LSTM_LO_SENS_2A,
                                                STOCK_NAME_edited,
                                                'Panel E', 'Panel F')

# %%
df_perf_metr_LS_LSTM = performance_metrics_SENS_LS("**Long Short**", 
                                                df_EC_LSTM_LS_BM, 
                                                df_EC_LSTM_LS_BM, 
                                                # df_EC_LSTM_LS_SENS_0,
                                                # df_EC_LSTM_LS_SENS_0A,
                                                df_EC_LSTM_LS_SENS_1, 
                                                df_EC_LSTM_LS_SENS_1A, 
                                                df_EC_LSTM_LS_SENS_2, 
                                                df_EC_LSTM_LS_SENS_2A,
                                                STOCK_NAME_edited,
                                                'Panel G', 'Panel H')

# %%
df_perf_metr_LO_LSTM
# Out:
#                                                           ARC(%)     ASD(%)  \
# &nbsp;                                    **FTSE 100**      2.39      18.03
# &nbsp;                                          &nbsp;       NaN        NaN
# **Long Only**              Base Case (Dropout = 0.075)      2.68      14.32
# **Panel E: Dropout Rate**               Dropout = 0.05  **2.85**       13.1
#                                          Dropout = 0.1      2.78  **11.99**
# None                                            &nbsp;       NaN        NaN
# **Panel F: Batch Size**    Base Case (Batch Size = 32)  **2.68**      14.32
#                                        Batch Size = 16      2.03  **13.84**
#                                        Batch Size = 64     -0.59      14.09
# None                                            &nbsp;       NaN        NaN
#
#                                MD(%)       MLD     IR*(%)   IR**(%)
# ...

# %%
df_perf_metr_LS_LSTM
# Out:
#                                                           ARC(%)     ASD(%)  \
# **Long Short**             Base Case (Dropout = 0.075)      2.28  **18.03**
# **Panel G: Dropout Rate**               Dropout = 0.05      4.96  **18.03**
#                                          Dropout = 0.1  **5.96**      18.05
# None                                            &nbsp;       NaN        NaN
# **Panel H: Batch Size**    Base Case (Batch Size = 32)      2.28  **18.03**
#                                        Batch Size = 16  **6.53**  **18.03**
#                                        Batch Size = 64      2.28      18.04
# None                                            &nbsp;       NaN        NaN
#
#                                MD(%)       MLD     IR*(%)   IR**(%)
# **Long Short**             **42.92**      11.3      12.67      0.67
# **Panel G: Dropout Rate**      63.39      13.7      27.49      2.15
#                                44.81  **6.09**   **33.0**  **4.39**
# ...

# %%
df_perf_metr_LO_LSTM.to_csv(f'./PERF_METR_RESULTS/{STOCK_NAME}/df_perf_metr_LO_LSTM.csv')
df_perf_metr_LS_LSTM.to_csv(f'./PERF_METR_RESULTS/{STOCK_NAME}/df_perf_metr_LS_LSTM.csv')

# %% [markdown]
# # Sensitivity Analysis - ARIMA-LSTM

# %%
STOCK_NAME = "FTSE 100"

df_EC_ARIMA_LSTM_LO_BM = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/RANDOM_SEARCH_1A/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LSTM_LS_BM = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/RANDOM_SEARCH_1A/Visualisations/df_EC_LS_MAIN.csv')

# df_EC_ARIMA_LSTM_LO_SENS_0 = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/SENS_0/Visualisations/df_EC_LO_MAIN.csv')
# df_EC_ARIMA_LSTM_LS_SENS_0 = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/SENS_0/Visualisations/df_EC_LS_MAIN.csv')

# df_EC_ARIMA_LSTM_LO_SENS_0A = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/SENS_0A/Visualisations/df_EC_LO_MAIN.csv')
# df_EC_ARIMA_LSTM_LS_SENS_0A = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/SENS_0A/Visualisations/df_EC_LS_MAIN.csv')

df_EC_ARIMA_LSTM_LO_SENS_1 = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/SENS_1/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LSTM_LS_SENS_1 = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/SENS_1/Visualisations/df_EC_LS_MAIN.csv')

df_EC_ARIMA_LSTM_LO_SENS_1A = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/SENS_1A/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LSTM_LS_SENS_1A = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/SENS_1A/Visualisations/df_EC_LS_MAIN.csv')

df_EC_ARIMA_LSTM_LO_SENS_2 = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/SENS_2/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LSTM_LS_SENS_2 = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/SENS_2/Visualisations/df_EC_LS_MAIN.csv')

df_EC_ARIMA_LSTM_LO_SENS_2A = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/SENS_2A/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LSTM_LS_SENS_2A = pd.read_csv(f'../ARIMA-LSTM/Results/FTSE100/Sensitivity Analysis/SENS_2A/Visualisations/df_EC_LS_MAIN.csv')

# %%
df_perf_metr_LO_ARIMA_LSTM = performance_metrics_SENS("**Long Only**", 
                                                      df_EC_ARIMA_LSTM_LO_BM, 
                                                      df_EC_ARIMA_LSTM_LO_BM, 
                                                    #   df_EC_ARIMA_LSTM_LO_SENS_0,
                                                    #   df_EC_ARIMA_LSTM_LO_SENS_0A,
                                                      df_EC_ARIMA_LSTM_LO_SENS_1, 
                                                      df_EC_ARIMA_LSTM_LO_SENS_1A, 
                                                      df_EC_ARIMA_LSTM_LO_SENS_2, 
                                                      df_EC_ARIMA_LSTM_LO_SENS_2A, 
                                                      STOCK_NAME_edited,
                                                      'Panel E', 'Panel F')

# %%
df_perf_metr_LS_ARIMA_LSTM = performance_metrics_SENS_LS("**Long Short**", 
                                                      df_EC_ARIMA_LSTM_LS_BM, 
                                                      df_EC_ARIMA_LSTM_LS_BM, 
                                                    #   df_EC_ARIMA_LSTM_LO_SENS_0,
                                                    #   df_EC_ARIMA_LSTM_LO_SENS_0A,
                                                      df_EC_ARIMA_LSTM_LS_SENS_1, 
                                                      df_EC_ARIMA_LSTM_LS_SENS_1A, 
                                                      df_EC_ARIMA_LSTM_LS_SENS_2, 
                                                      df_EC_ARIMA_LSTM_LS_SENS_2A, 
                                                      STOCK_NAME_edited,
                                                      'Panel G', 'Panel H')

# %%
df_perf_metr_LO_ARIMA_LSTM
# Out:
#                                                           ARC(%)     ASD(%)  \
# &nbsp;                                    **FTSE 100**      2.39      18.03
# &nbsp;                                          &nbsp;       NaN        NaN
# **Long Only**              Base Case (Dropout = 0.075)  **5.47**      13.79
# **Panel E: Dropout Rate**               Dropout = 0.05      2.66      13.36
#                                          Dropout = 0.1      2.85  **10.94**
# None                                            &nbsp;       NaN        NaN
# **Panel F: Batch Size**    Base Case (Batch Size = 32)  **5.47**      13.79
#                                        Batch Size = 16      2.88  **13.63**
#                                        Batch Size = 64      0.44      14.25
# None                                            &nbsp;       NaN        NaN
#
#                                MD(%)       MLD     IR*(%)   IR**(%)
# ...

# %%
df_perf_metr_LS_ARIMA_LSTM
# Out:
#                                                            ARC(%)     ASD(%)  \
# **Long Short**             Base Case (Dropout = 0.075)  **10.98**  **18.02**
# **Panel G: Dropout Rate**               Dropout = 0.05       4.91  **18.02**
#                                          Dropout = 0.1       3.61      18.03
# None                                            &nbsp;        NaN        NaN
# **Panel H: Batch Size**    Base Case (Batch Size = 32)  **10.98**  **18.02**
#                                        Batch Size = 16      -0.63      18.03
#                                        Batch Size = 64       3.98      18.04
# None                                            &nbsp;        NaN        NaN
#
#                                MD(%)        MLD     IR*(%)    IR**(%)
# **Long Short**             **40.17**      10.89  **60.92**  **16.65**
# **Panel G: Dropout Rate**      44.39       7.59      27.24       3.01
# ...

# %%
df_perf_metr_LO_ARIMA_LSTM.to_csv(f'./PERF_METR_RESULTS/{STOCK_NAME}/df_perf_metr_LO_ARIMA_LSTM.csv')
df_perf_metr_LS_ARIMA_LSTM.to_csv(f'./PERF_METR_RESULTS/{STOCK_NAME}/df_perf_metr_LS_ARIMA_LSTM.csv')

# %% [markdown]
# # Sensitivity Analysis - ARIMA

# %%
STOCK_NAME = "FTSE 100"

df_EC_ARIMA_LO_BM = pd.read_csv(f'../ARIMA/Results/FTSE100/Sensitivity Analysis/RANDOM_SEARCH_1/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LS_BM = pd.read_csv(f'../ARIMA/Results/FTSE100/Sensitivity Analysis/RANDOM_SEARCH_1/Visualisations/df_EC_LS_MAIN.csv')

# df_EC_ARIMA_LO_SENS_0 = pd.read_csv(f'../ARIMA/Results/FTSE100/Sensitivity Analysis/SENS_0/Visualisations/df_EC_LO_MAIN.csv')
# df_EC_ARIMA_LS_SENS_0 = pd.read_csv(f'../ARIMA/Results/FTSE100/Sensitivity Analysis/SENS_0/Visualisations/df_EC_LS_MAIN.csv')

# df_EC_ARIMA_LO_SENS_0A = pd.read_csv(f'../ARIMA/Results/FTSE100/Sensitivity Analysis/SENS_0A/Visualisations/df_EC_LO_MAIN.csv')
# df_EC_ARIMA_LS_SENS_0A = pd.read_csv(f'../ARIMA/Results/FTSE100/Sensitivity Analysis/SENS_0A/Visualisations/df_EC_LS_MAIN.csv')

df_EC_ARIMA_LO_SENS_B = pd.read_csv(f'../ARIMA/Results/FTSE100/Sensitivity Analysis/SENS_B/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LS_SENS_B = pd.read_csv(f'../ARIMA/Results/FTSE100/Sensitivity Analysis/SENS_B/Visualisations/df_EC_LS_MAIN.csv')

df_EC_ARIMA_LO_SENS_C = pd.read_csv(f'../ARIMA/Results/FTSE100/Sensitivity Analysis/SENS_C/Visualisations/df_EC_LO_MAIN.csv')
df_EC_ARIMA_LS_SENS_C = pd.read_csv(f'../ARIMA/Results/FTSE100/Sensitivity Analysis/SENS_C/Visualisations/df_EC_LS_MAIN.csv')

# %%
df_perf_metr_LO_ARIMA = performance_metrics_SENS_ARIMA("**Long Only**", 
                                                      df_EC_ARIMA_LO_BM, 
                                                      df_EC_ARIMA_LO_BM, 
                                                    #   df_EC_ARIMA_LO_SENS_0,
                                                    #   df_EC_ARIMA_LO_SENS_0A,
                                                      df_EC_ARIMA_LO_SENS_B, 
                                                      df_EC_ARIMA_LO_SENS_C, 
                                                      STOCK_NAME_edited)

# %%
df_perf_metr_LS_ARIMA = performance_metrics_SENS_ARIMA_LS("**Long Short**", 
                                                      df_EC_ARIMA_LS_BM, 
                                                      df_EC_ARIMA_LS_BM, 
                                                    #   df_EC_ARIMA_LS_SENS_0,
                                                    #   df_EC_ARIMA_LS_SENS_0A,
                                                      df_EC_ARIMA_LS_SENS_B, 
                                                      df_EC_ARIMA_LS_SENS_C, 
                                                      STOCK_NAME_edited)

# %%
df_perf_metr_LO_ARIMA
# Out:
#                                                ARC(%)     ASD(%)      MD(%)  \
#                               **FTSE 100**       2.39      18.03      47.83
#                                     &nbsp;        NaN        NaN        NaN
# **Long Only**                    Base Case      -3.78  **12.88**      58.12
#                  Order Range = {0-3,1,0-3}      -3.06       12.9  **57.55**
#                Information Criterion = BIC  **-3.02**       12.9  **57.55**
#                                     &nbsp;        NaN        NaN        NaN
#
#                      MLD   IR*(%)  IR**(%)
#                     5.94    13.27     0.66
#                      NaN      NaN      NaN
# **Long Only**  **12.55**  **0.0**  **0.0**
#                **12.55**  **0.0**  **0.0**
#                **12.55**  **0.0**  **0.0**
#                      NaN      NaN      NaN

# %%
df_perf_metr_LS_ARIMA
# Out:
#                                                ARC(%)     ASD(%)      MD(%)  \
# **Long Short**                    Base Case      0.84  **18.04**  **53.65**
#                   Order Range = {0-3,1,0-3}  **2.46**  **18.04**  **53.65**
#                 Information Criterion = BIC      2.37  **18.04**  **53.65**
#                                      &nbsp;       NaN        NaN        NaN
#
#                      MLD     IR*(%)   IR**(%)
# **Long Short**  **8.03**       4.66      0.07
#                 **8.03**  **13.66**  **0.63**
#                 **8.03**      13.15      0.58
#                      NaN        NaN       NaN

# %%
df_perf_metr_LO_ARIMA.to_csv(f'./PERF_METR_RESULTS/{STOCK_NAME}/df_perf_metr_LO_ARIMA.csv')
df_perf_metr_LS_ARIMA.to_csv(f'./PERF_METR_RESULTS/{STOCK_NAME}/df_perf_metr_LS_ARIMA.csv')
